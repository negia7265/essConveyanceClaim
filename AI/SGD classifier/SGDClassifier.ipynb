# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
import multiprocessing
from gensim.models import Word2Vec
import re # For preprocessing
import pandas as pd # For data handling
from nltk.stem import WordNetLemmatizer
from sklearn.metrics import accuracy_score
from sklearn.linear_model import SGDClassifier
lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words('english'))
stop_words.remove('m')  #meter word must not be removed during preprocessing

# %%
def preprocess_text(text):
    #remove punctuation mark from the text
    text=text.translate(str.maketrans('','',''',!"#%&'()*+-/:;<=.>?@[\]^_`{|}~'''))
    #remove new line characters
    text=text.replace('\n', ' ')
    # lower case each letter of the word
    text=text.lower()
    #including space in beween {num}{word} 
    text=re.sub(r'(\d+)([a-z]+)', r'\1 \2', text)
    # split the words into tokens
    tokens=word_tokenize(text)
    # remove stop words 
    tokens = [word for word in tokens if word not in stop_words]
    #all words to root words
    stemmer = PorterStemmer()
    tokens = [stemmer.stem(word) for word in tokens]
    #lemmatization
    lemmatized = [lemmatizer.lemmatize(token) for token in tokens]
    return ' '.join(lemmatized) 
def text_refine(text):
  return re.findall(r'\b[a-zA-Z]+\b', text)

# %%
# def get_content(invoice):
#     df=pd.read_csv(invoice)
#     content=df['invoice_content'].apply(lambda x: text_refine(preprocess_text(x)))
#     return content
# dataset=[]
# dataset.extend(get_content('OLA.csv'))
# dataset.extend(get_content('UBER.csv'))
# dataset.extend(get_content('RAPIDO.csv'))

# %%
#print(len(dataset))

# %%
km_m_dataset = [
  "10 kilometers is a decent distance.",
  "I walked a few kilometres today.",
  "The marathon is 42 kilometers long.",
  "My road trip covered 500 km.",
  "The sign said the next town is 15 kilometers away.",
  "I jogged 5 km this morning.",
  "The cycling trail spans 30 kilometres.",
  "The distance between cities is 75 km.",
  "The hike is 20 kilometres round trip.",
  "We're just 2 km from the destination.",
  "The race is a challenging 50 kms.",
  "I drove for 200 kilometers straight.",
  "The scenic route is 60 kilometers in length.",
  "The detour added 5 more kilometres.",
  "My daily run is only 3 km.",
  "The tour covers 100 kilometers.",
  "It's a short drive, just 15 km.",
  "We cycled for 25 kilometres today.",
  "The map indicates 40 km to the border.",
  "The village is located 8 km away.",
  "I can run 8 kilometeres without stopping.",
  "The nature trail is 12 kilometer long.",
  "The highway stretch is 200 km.",
  "The town is just 5 kms ahead.",
  "We're almost there, just 3 kilometers more.",
  "The GPS shows 30 km to the next turn.",
  "The scenic route is 55 kilometres.",
  "I covered 12 km on my morning walk.",
  "The remote village is 50 kilometers away.",
  "The cycling event is 75 kilometer.",
  "I biked 15 kilometres yesterday.",
  "The scenic drive is 80 km long.",
  "The mountain trail is 10 km uphill.",
  "The road trip spans 250 kilometers.",
  "The city is just 7 kilometres away.",
  "The marathon route measures 35 km.",
  "The cycling challenge is 60 kms.",
  "The GPS says we have 25 km to go.",
  "The hiking trail is 18 kilometres.",
  "I ran 6 km before breakfast.",
  "The country road is 45 kilometer.",
  "We drove for 180 kilometres today.",
  "The sign says the beach is 20 km away.",
  "The race is a grueling 80 km.",
  "The scenic route spans 70 kilometres.",
  "I walked 2 km in the park.",
  "The mountain trail is 25 km long.",
  "The town is just 10 kms away.",
  "We're covering 50 kilometres per hour.",
  "The cycling route is 90 km.",
  "10 meters is a decent distance.",
  "I walked a few meters today.",
  "The marathon is 42 m long.",
  "My road trip covered 500 m.",
  "The sign said the next town is 15 meters away.",
  "I jogged 5 m this morning.",
  "The cycling trail spans 30 metres.",
  "The distance between cities is 75 m.",
  "The hike is 20 meters round trip.",
  "We're just 2 m from the destination.",
  "The race is a challenging 50 metres.",
  "I drove for 200 metres straight.",
  "The scenic route is 60 m in length.",
  "The detour added 5 more metres.",
  "My daily run is only 3 m.",
  "The tour covers 100 metres.",
  "It's a short drive, just 15 m.",
  "We cycled for 25 metres today.",
  "The map indicates 40 meters to the border.",
  "The village is located 8 m away.",
  "I can run 8 metres without stopping.",
  "The nature trail is 12 m long.",
  "The highway stretch is 200 meters.",
  "The town is just 5 m ahead.",
  "We're almost there, just 3 meters more.",
  "The GPS shows 30 m to the next turn.",
  "The scenic route is 55 metres.",
  "I covered 12 m on my morning walk.",
  "The remote village is 50 m away.",
  "The cycling event is 75 meter.",
  "I biked 15 metres yesterday.",
  "The scenic drive is 80 m long.",
  "The mountain trail is 10 m uphill.",
  "The road trip spans 250 m.",
  "The city is just 7 metres away.",
  "The marathon route measures 35 m.",
  "The cycling challenge is 60 metres.",
  "The GPS says we have 25 m to go.",
  "The hiking trail is 18 metres.",
  "I ran 6 m before breakfast.",
  "The country road is 45 m.",
  "We drove for 180 metres today.",
  "The sign says the beach is 20 m away.",
  "The race is a grueling 80 meter.",
  "The scenic route spans 70 metres.",
  "I walked 2 meter in the park.",
  "The mountain trail is 25 m long.",
  "The town is just 10 metr away.",
  "We're covering 50 metres per hour.",
  "The cycling route is 90 meter."
]
dataset=[]
for x in km_m_dataset:
   dataset.extend(text_refine(preprocess_text(x)))

# %%
dataset
# Out:
# ['kilomet',
#  'decent',
#  'distanc',
#  'walk',
#  'kilometr',
#  'today',
#  'marathon',
#  'kilomet',
#  'long',
#  'road',
#  'trip',
#  'cover',
#  'km',
#  'sign',
#  'said',
#  'next',
#  'town',
#  'kilomet',
#  'away',
#  'jog',
#  'km',
#  'morn',
#  'cycl',
#  'trail',
#  'span',
#  'kilometr',
#  'distanc',
#  'citi',
#  'km',
#  'hike',
#  'kilometr',
#  'round',
#  'trip',
#  'km',
#  'destin',
#  'race',
#  'challeng',
#  'km',
#  'drove',
#  'kilomet',
#  'straight',
#  'scenic',
#  'rout',
#  'kilomet',
#  'length',
#  'detour',
#  'ad',
#  'kilometr',
#  'daili',
#  'run',
#  'km',
#  'tour',
#  'cover',
#  'kilomet',
#  'short',
#  'drive',
#  'km',
#  'cycl',
#  'kilometr',
#  'today',
#  'map',
#  'indic',
#  'km',
#  'border',
#  'villag',
#  'locat',
#  'km',
#  'away',
#  'run',
#  'kilometer',
#  'without',
#  'stop',
#  'natur',
#  'trail',
#  'kilomet',
#  'long',
#  'highway',
#  'stretch',
#  'km',
#  'town',
#  'km',
#  'ahead',
#  'almost',
#  'kilomet',
#  'gp',
#  'show',
#  'km',
#  'next',
#  'turn',
#  'scenic',
#  'rout',
#  'kilometr',
#  'cover',
#  'km',
#  'morn',
#  'walk',
#  'remot',
#  'villag',
#  'kilomet',
#  'away',
#  'cycl',
#  'event',
#  'kilomet',
#  'bike',
#  'kilometr',
#  'yesterday',
#  'scenic',
#  'drive',
#  'km',
#  'long',
#  'mountain',
#  'trail',
#  'km',
#  'uphil',
#  'road',
#  'trip',
#  'span',
#  'kilomet',
#  'citi',
#  'kilometr',
#  'away',
#  'marathon',
#  'rout',
#  'measur',
#  'km',
#  'cycl',
#  'challeng',
#  'km',
#  'gp',
#  'say',
#  'km',
#  'go',
#  'hike',
#  'trail',
#  'kilometr',
#  'ran',
#  'km',
#  'breakfast',
#  'countri',
#  'road',
#  'kilomet',
#  'drove',
#  'kilometr',
#  'today',
#  'sign',
#  'say',
#  'beach',
#  'km',
#  'away',
#  'race',
#  'gruel',
#  'km',
#  'scenic',
#  'rout',
#  'span',
#  'kilometr',
#  'walk',
#  'km',
#  'park',
#  'mountain',
#  'trail',
#  'km',
#  'long',
#  'town',
#  'km',
#  'away',
#  'cover',
#  'kilometr',
#  'per',
#  'hour',
#  'cycl',
#  'rout',
#  'km',
#  'meter',
#  'decent',
#  'distanc',
#  'walk',
#  'meter',
#  'today',
#  'marathon',
#  'm',
#  'long',
#  'road',
#  'trip',
#  'cover',
#  'm',
#  'sign',
#  'said',
#  'next',
#  'town',
#  'meter',
#  'away',
#  'jog',
#  'm',
#  'morn',
#  'cycl',
#  'trail',
#  'span',
#  'metr',
#  'distanc',
#  'citi',
#  'm',
#  'hike',
#  'meter',
#  'round',
#  'trip',
#  'm',
#  'destin',
#  'race',
#  'challeng',
#  'metr',
#  'drove',
#  'metr',
#  'straight',
#  'scenic',
#  'rout',
#  'm',
#  'length',
#  'detour',
#  'ad',
#  'metr',
#  'daili',
#  'run',
#  'm',
#  'tour',
#  'cover',
#  'metr',
#  'short',
#  'drive',
#  'm',
#  'cycl',
#  'metr',
#  'today',
#  'map',
#  'indic',
#  'meter',
#  'border',
#  'villag',
#  'locat',
#  'm',
#  'away',
#  'run',
#  'metr',
#  'without',
#  'stop',
#  'natur',
#  'trail',
#  'm',
#  'long',
#  'highway',
#  'stretch',
#  'meter',
#  'town',
#  'm',
#  'ahead',
#  'almost',
#  'meter',
#  'gp',
#  'show',
#  'm',
#  'next',
#  'turn',
#  'scenic',
#  'rout',
#  'metr',
#  'cover',
#  'm',
#  'morn',
#  'walk',
#  'remot',
#  'villag',
#  'm',
#  'away',
#  'cycl',
#  'event',
#  'meter',
#  'bike',
#  'metr',
#  'yesterday',
#  'scenic',
#  'drive',
#  'm',
#  'long',
#  'mountain',
#  'trail',
#  'm',
#  'uphil',
#  'road',
#  'trip',
#  'span',
#  'm',
#  'citi',
#  'metr',
#  'away',
#  'marathon',
#  'rout',
#  'measur',
#  'm',
#  'cycl',
#  'challeng',
#  'metr',
#  'gp',
#  'say',
#  'm',
#  'go',
#  'hike',
#  'trail',
#  'metr',
#  'ran',
#  'm',
#  'breakfast',
#  'countri',
#  'road',
#  'm',
#  'drove',
#  'metr',
#  'today',
#  'sign',
#  'say',
#  'beach',
#  'm',
#  'away',
#  'race',
#  'gruel',
#  'meter',
#  'scenic',
#  'rout',
#  'span',
#  'metr',
#  'walk',
#  'meter',
#  'park',
#  'mountain',
#  'trail',
#  'm',
#  'long',
#  'town',
#  'metr',
#  'away',
#  'cover',
#  'metr',
#  'per',
#  'hour',
#  'cycl',
#  'rout',
#  'meter']

# %%
def build_estimated_training_set():
    Y=[]
    km_units={'km','kilomet',"kilometr"}
    m_units={'m','metr','meter'}
    for word in dataset:
        if word in km_units or word in m_units:
           Y.append(1)
        else:
           Y.append(0)
    return Y

# %%
y_train=build_estimated_training_set()

# %%
cores=multiprocessing.cpu_count()
cores
# Out:
# 8

# %%
w2v_model = Word2Vec(window=2,min_count=1,workers=cores-1)
w2v_model.build_vocab([dataset])

# %%
# print('unique words:', len(w2v_model.wv))
w2v_model.wv.index_to_key
# Out:
# ['km',
#  'm',
#  'metr',
#  'kilometr',
#  'away',
#  'kilomet',
#  'meter',
#  'trail',
#  'cycl',
#  'rout',
#  'scenic',
#  'long',
#  'cover',
#  'span',
#  'trip',
#  'road',
#  'town',
#  'walk',
#  'today',
#  'mountain',
#  'drove',
#  'challeng',
#  'run',
#  'race',
#  'drive',
#  'hike',
#  'citi',
#  'villag',
#  'marathon',
#  'distanc',
#  'morn',
#  'say',
#  'next',
#  'gp',
#  'sign',
#  'decent',
#  'jog',
#  'per',
#  'round',
#  'destin',
#  'said',
#  'hour',
#  'straight',
#  'gruel',
#  'ad',
#  'length',
#  'ahead',
#  'countri',
#  'breakfast',
#  'ran',
#  'go',
#  'measur',
#  'uphil',
#  'yesterday',
#  'bike',
#  'event',
#  'remot',
#  'turn',
#  'show',
#  'almost',
#  'stretch',
#  'detour',
#  'highway',
#  'natur',
#  'stop',
#  'without',
#  'locat',
#  'border',
#  'indic',
#  'map',
#  'short',
#  'park',
#  'daili',
#  'beach',
#  'tour',
#  'kilometer']

# %%
w2v_model.train(dataset, total_examples=w2v_model.corpus_count, epochs=20)
# Out:
# (330, 31060)

# %%
w2v_model.wv.most_similar('m')
# Out:
# [('villag', 0.18890605866909027),
#  ('run', 0.18855659663677216),
#  ('measur', 0.18359005451202393),
#  ('trip', 0.16072483360767365),
#  ('kilometer', 0.15974178910255432),
#  ('today', 0.15923379361629486),
#  ('border', 0.15861040353775024),
#  ('span', 0.13725273311138153),
#  ('stop', 0.13463549315929413),
#  ('race', 0.127894327044487)]

# %%
# from gensim.models import KeyedVectors
word_vectors = w2v_model.wv
# word_vectors.save('vectors.kv')

# %%
import numpy as np
from sklearn.linear_model import SGDClassifier
def doc_to_vec(words):
    vec=[]
    for word in words:
       vec.append(word_vectors[word])
    return vec
x_train=doc_to_vec(dataset)

# %%
clf = SGDClassifier(loss='log_loss', verbose=True)

# %%
clf.fit(x_train, y_train)
# Out:
# -- Epoch 1
# Norm: 13.64, NNZs: 100, Bias: -4.632144, T: 346, Avg. loss: 1.804008
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 21.23, NNZs: 100, Bias: 2.387624, T: 692, Avg. loss: 1.297429
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 25.86, NNZs: 100, Bias: -2.956223, T: 1038, Avg. loss: 1.033504
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 28.33, NNZs: 100, Bias: -3.218894, T: 1384, Avg. loss: 0.826482
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 30.52, NNZs: 100, Bias: 0.529117, T: 1730, Avg. loss: 0.759452
# Total training time: 0.00 seconds.
# -- Epoch 6
# Norm: 31.81, NNZs: 100, Bias: -3.194975, T: 2076, Avg. loss: 0.677497
# Total training time: 0.00 seconds.
# -- Epoch 7
# Norm: 32.93, NNZs: 100, Bias: -2.414613, T: 2422, Avg. loss: 0.620576
# Total training time: 0.00 seconds.
# -- Epoch 8
# Norm: 33.86, NNZs: 100, Bias: -2.515409, T: 2768, Avg. loss: 0.614511
# Total training time: 0.00 seconds.
# -- Epoch 9
# Norm: 34.38, NNZs: 100, Bias: -0.060901, T: 3114, Avg. loss: 0.556952
# Total training time: 0.00 seconds.
# -- Epoch 10
# Norm: 34.94, NNZs: 100, Bias: -1.947094, T: 3460, Avg. loss: 0.570651
# Total training time: 0.00 seconds.
# -- Epoch 11
# Norm: 35.55, NNZs: 100, Bias: -3.128451, T: 3806, Avg. loss: 0.573218
# Total training time: 0.00 seconds.
# -- Epoch 12
# Norm: 35.94, NNZs: 100, Bias: -0.341819, T: 4152, Avg. loss: 0.536483
# Total training time: 0.00 seconds.
# -- Epoch 13
# Norm: 36.27, NNZs: 100, Bias: -1.447663, T: 4498, Avg. loss: 0.533841
# Total training time: 0.00 seconds.
# -- Epoch 14
# Norm: 36.45, NNZs: 100, Bias: -2.169757, T: 4844, Avg. loss: 0.504452
# Total training time: 0.00 seconds.
# -- Epoch 15
# Norm: 36.63, NNZs: 100, Bias: -1.713055, T: 5190, Avg. loss: 0.507759
# Total training time: 0.00 seconds.
# -- Epoch 16
# Norm: 36.79, NNZs: 100, Bias: -2.945345, T: 5536, Avg. loss: 0.500944
# Total training time: 0.00 seconds.
# -- Epoch 17
# Norm: 37.03, NNZs: 100, Bias: -0.858323, T: 5882, Avg. loss: 0.516038
# Total training time: 0.00 seconds.
# -- Epoch 18
# Norm: 37.17, NNZs: 100, Bias: -1.811051, T: 6228, Avg. loss: 0.508926
# Total training time: 0.00 seconds.
# -- Epoch 19
# Norm: 37.34, NNZs: 100, Bias: -1.275377, T: 6574, Avg. loss: 0.500178
# Total training time: 0.00 seconds.
# -- Epoch 20
# Norm: 37.48, NNZs: 100, Bias: -1.797024, T: 6920, Avg. loss: 0.499096
# Total training time: 0.00 seconds.
# -- Epoch 21
# Norm: 37.60, NNZs: 100, Bias: -0.215569, T: 7266, Avg. loss: 0.490360
# Total training time: 0.00 seconds.
# -- Epoch 22
# Norm: 37.70, NNZs: 100, Bias: -1.606674, T: 7612, Avg. loss: 0.488937
# Total training time: 0.00 seconds.
# -- Epoch 23
# Norm: 37.75, NNZs: 100, Bias: 0.086698, T: 7958, Avg. loss: 0.465957
# Total training time: 0.00 seconds.
# -- Epoch 24
# Norm: 37.83, NNZs: 100, Bias: -0.067100, T: 8304, Avg. loss: 0.481877
# Total training time: 0.00 seconds.
# -- Epoch 25
# Norm: 37.89, NNZs: 100, Bias: -0.968070, T: 8650, Avg. loss: 0.478258
# Total training time: 0.01 seconds.
# -- Epoch 26
# Norm: 37.97, NNZs: 100, Bias: -1.333984, T: 8996, Avg. loss: 0.476332
# Total training time: 0.01 seconds.
# -- Epoch 27
# Norm: 38.00, NNZs: 100, Bias: -1.400129, T: 9342, Avg. loss: 0.467609
# Total training time: 0.01 seconds.
# -- Epoch 28
# Norm: 38.07, NNZs: 100, Bias: -1.918852, T: 9688, Avg. loss: 0.476035
# Total training time: 0.01 seconds.
# Convergence after 28 epochs took 0.01 seconds
# SGDClassifier(loss='log_loss', verbose=True)

# %%
y_test=[clf.predict([x]) for x in x_train]
accuracy = accuracy_score(y_train,y_test)
print("Accuracy:", accuracy*100,"%")
# Out:
# Accuracy: 71.38728323699422 %

# %%
import joblib
joblib.dump(clf, 'distance_model.joblib')
# Out:
# ['distance_model.joblib']

# %%
w2v_model.save('km_m_model.w2v')
